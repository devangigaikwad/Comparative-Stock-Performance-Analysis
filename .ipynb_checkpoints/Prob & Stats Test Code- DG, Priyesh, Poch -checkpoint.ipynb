# %% [markdown]
# # Test Code for Prob & Stats Final Project

# %%
import datetime
import numpy as np
import pandas as pd
# %matplotlib inline
import pandas_datareader.data as web
# import fix_yahoo_finance as yf
from pandas_datareader import data as web
import yfinance as yf
from scipy import stats
import matplotlib.pyplot as plt

# %%
symbols = ['HSBA.L','NWG.L','TSCO.L','BARC.L', 'LLOY.L']

# %%
raw_data = yf.download(symbols, start = '2016-06-23', end='2016-8-23') #start date is 2013/1/1 and end date is 2013/1/2
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
raw_data.head()
# Out:
#              Adj Close                                                 \
#                 BARC.L      HSBA.L     LLOY.L       NWG.L      TSCO.L
# Date
# 2016-06-23  156.668869  330.273346  53.643814  204.849136  147.944580
# 2016-06-24  128.972107  325.549408  42.379730  167.886322  143.095428
# 2016-06-27  106.596840  318.318207  38.030231  142.535675  135.468979
# 2016-06-28  110.200348  322.387970  40.855549  142.126862  141.464310
# 2016-06-29  115.605614  329.037781  41.279343  147.360519  150.501480
#
#                  Close                                                 ...  \
#                 BARC.L      HSBA.L     LLOY.L       NWG.L      TSCO.L  ...
# Date                                                                   ...
# 2016-06-23  186.949997  454.450012  72.150002  269.769196  212.546494  ...
# 2016-06-24  153.899994  447.950012  57.000000  221.092300  205.579895  ...
# 2016-06-27  127.199997  438.000000  51.150002  187.707596  194.623199  ...
# ...

# %%
raw_data['Close'].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
log_return = np.log(raw_data['Close'] / raw_data['Open'])

# %%
log_return.hist(bins = 50, figsize = (10, 10))
# Out:
# array([[<AxesSubplot: title={'center': 'BARC.L'}>,
#         <AxesSubplot: title={'center': 'HSBA.L'}>],
#        [<AxesSubplot: title={'center': 'LLOY.L'}>,
#         <AxesSubplot: title={'center': 'NWG.L'}>],
#        [<AxesSubplot: title={'center': 'TSCO.L'}>, <AxesSubplot: >]],
#       dtype=object)

# %%
ax1 = plt.subplot(221)
# x = stats.t.rvs(3, size=nsample, random_state=rng)
res = stats.probplot(log_return['BARC.L'], plot=plt)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [55], in <cell line: 3>()
#       1 ax1 = plt.subplot(221)
#       2 # x = stats.t.rvs(3, size=nsample, random_state=rng)
# ----> 3 res = stats.probplot(log_return['BARC.L'], plot=plt, title='a')
#
# TypeError: probplot() got an unexpected keyword argument 'title'

# %%
fig, axs = plt.subplots(ncols=2, nrows=3, figsize=(10, 10))

for i, sym in enumerate(symbols):
    
    r = i//2
    c = i%2
    
    res = stats.probplot(log_return[sym], plot=axs[r, c])
    axs[r, c].set_title(sym)
